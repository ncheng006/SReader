# %%
from ibm_watson import SpeechToTextV1
from ibm_watson.websocket import RecognizeCallback, AudioSource 
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# %%
api_key = "ak2Z9IIJtbF90H-UcCGV3fviteGlCP-Jxoq0WTp442X4"
url = "https://api.us-south.speech-to-text.watson.cloud.ibm.com/instances/03c19b2a-6978-4be6-a183-b1a895a5f75f"

# %%
authenticator = IAMAuthenticator(api_key)
stt = SpeechToTextV1(authenticator=authenticator)
stt.set_service_url(url)

# %%
print(5)
# Out:
# 5

# %%
with open('audio-file.flac', 'rb') as f:
    res = stt.recognize(audio=f, content_type='audio/flac', model='en-US_NarrowbandModel', word_confidence=True, audio_metrics=False, timestamps=True).get_result()

# %%
res
# Out:
# {'result_index': 0,
#  'results': [{'final': True,
#    'alternatives': [{'transcript': 'several tornadoes touched down as a line of severe thunderstorms swept through Colorado on Sunday ',
#      'confidence': 0.92,
#      'timestamps': [['several', 1.01, 1.52],
#       ['tornadoes', 1.52, 2.15],
#       ['touched', 2.15, 2.54],
#       ['down', 2.54, 2.82],
#       ['as', 2.82, 2.92],
#       ['a', 2.92, 3.0],
#       ['line', 3.0, 3.3],
#       ['of', 3.3, 3.4],
#       ['severe', 3.4, 3.79],
#       ['thunderstorms', 3.79, 4.51],
#       ['swept', 4.51, 4.78],
#       ['through', 4.78, 4.96],
#       ['Colorado', 4.96, 5.59],
#       ['on', 5.59, 5.73],
#       ['Sunday', 5.73, 6.36]],
#      'word_confidence': [['several', 1.0],
#       ['tornadoes', 1.0],
#       ['touched', 0.65],
#       ['down', 1.0],
#       ['as', 0.61],
#       ['a', 1.0],
#       ['line', 1.0],
#       ['of', 1.0],
#       ['severe', 1.0],
#       ['thunderstorms', 0.83],
#       ['swept', 1.0],
# ...

# %%
text = res['results'][0]['alternatives'][0]['transcript']
text
# Out:
# 'several tornadoes touched down as a line of severe thunderstorms swept through Colorado on Sunday '

# %%
confidence = res['results'][0]['alternatives'][0]['confidence']
confidence
# Out:
# 0.92

# %%
with open('output.txt', 'w') as out:
    out.writelines(text)

# %%
text
# Out:
# 'several tornadoes touched down as a line of severe thunderstorms swept through Colorado on Sunday '

# %%
res
# Out:
# {'result_index': 0,
#  'results': [{'final': True,
#    'alternatives': [{'transcript': 'several tornadoes touched down as a line of severe thunderstorms swept through Colorado on Sunday ',
#      'confidence': 0.92,
#      'timestamps': [['several', 1.01, 1.52],
#       ['tornadoes', 1.52, 2.15],
#       ['touched', 2.15, 2.54],
#       ['down', 2.54, 2.82],
#       ['as', 2.82, 2.92],
#       ['a', 2.92, 3.0],
#       ['line', 3.0, 3.3],
#       ['of', 3.3, 3.4],
#       ['severe', 3.4, 3.79],
#       ['thunderstorms', 3.79, 4.51],
#       ['swept', 4.51, 4.78],
#       ['through', 4.78, 4.96],
#       ['Colorado', 4.96, 5.59],
#       ['on', 5.59, 5.73],
#       ['Sunday', 5.73, 6.36]],
#      'word_confidence': [['several', 1.0],
#       ['tornadoes', 1.0],
#       ['touched', 0.65],
#       ['down', 1.0],
#       ['as', 0.61],
#       ['a', 1.0],
#       ['line', 1.0],
#       ['of', 1.0],
#       ['severe', 1.0],
#       ['thunderstorms', 0.83],
#       ['swept', 1.0],
# ...

# %%
import websocket

def on_message(wsapp, message):
    print(message)

wsapp = websocket.WebSocketApp("wss://stream.meetup.com/2/rsvps", on_message=on_message)
wsapp.run_forever()
# Out:
# {"venue":{"venue_name":"John Knight Memorial Park","lon":149.074341,"lat":-35.238956,"venue_id":13147102},"visibility":"public","response":"yes","guests":0,"member":{"member_id":294909506,"photo":"https:\/\/secure.meetupstatic.com\/photos\/member\/4\/a\/0\/b\/thumb_301098955.jpeg","member_name":"Lynette Sprott"},"rsvp_id":1891600398,"mtime":1634976462350,"event":{"event_name":"Lighthouse walk-by-bar and picnic","event_id":"281312901","time":1636167600000,"event_url":"https:\/\/www.meetup.com\/Canberra-Solo-Lifestyle\/events\/281312901\/"},"group":{"group_topics":[{"urlkey":"singles-40s-50s","topic_name":"Singles 40's - 50's"},{"urlkey":"singles-60-over","topic_name":"Singles 60 & over"},{"urlkey":"dating-and-relationships","topic_name":"Dating and Relationships"},{"urlkey":"singles-30s-50s","topic_name":"Singles 30's-50's"},{"urlkey":"socialnetwork","topic_name":"Social Networking"},{"urlkey":"diningout","topic_name":"Dining Out"},{"urlkey":"singles-30s-and-40s","topic_name":"Singles
# ...
